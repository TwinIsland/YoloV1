# %%
# In a terminal, Run the `download_data.sh` script in the data folder of assignment 3 part 2

# %%
import os
import random

import cv2
import numpy as np

import torch
from torch.utils.data import DataLoader
from torchvision import models

from src.resnet_yolo import resnet50
from yolo_loss import YoloLoss
from src.dataset import VocDetectorDataset
from src.eval_voc import evaluate
from src.predict import predict_image
from src.config import VOC_CLASSES, COLORS
from kaggle_submission import output_submission_csv

import matplotlib.pyplot as plt
import collections

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Initialization

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
# YOLO network hyperparameters
B = 2  # number of bounding box predictions per cell
S = 14  # width/height of network output grid (larger than 7x7 from paper since we use a different network)

# %% [markdown]
# To implement Yolo we will rely on a pretrained classifier as the backbone for our detection network. PyTorch offers a variety of models which are pretrained on ImageNet in the [`torchvision.models`](https://pytorch.org/docs/stable/torchvision/models.html) package. In particular, we will use the ResNet50 architecture as a base for our detector. This is different from the base architecture in the Yolo paper and also results in a different output grid size (14x14 instead of 7x7).
#
# Models are typically pretrained on ImageNet since the dataset is very large (> 1 million images) and widely used. The pretrained model provides a very useful weight initialization for our detector, so that the network is able to learn quickly and effectively.

# %%
load_network_path = None #'checkpoints/best_detector.pth' 
pretrained = True

# use to load a previously trained network
if load_network_path is not None:
    print('Loading saved network from {}'.format(load_network_path))
    net = resnet50().to(device)
    net.load_state_dict(torch.load(load_network_path))
else:
    print('Load pre-trained model')
    net = resnet50(pretrained=pretrained).to(device)
# Out:
# Load pre-trained model

# %%
learning_rate = 0.001
num_epochs = 50
batch_size = 10

# Yolo loss component coefficients (as given in Yolo v1 paper)
lambda_coord = 5
lambda_noobj = 0.1

# %% [markdown]
# ## Reading Pascal Data

# %% [markdown]
# Since Pascal is a small dataset (5000 in train+val) we have combined the train and val splits to train our detector. This is not typically a good practice, but we will make an exception in this case to be able to get reasonable detection results with a comparatively small object detection dataset.
#
# The train dataset loader also using a variety of data augmentation techniques including random shift, scaling, crop, and flips. Data augmentation is slightly more complicated for detection datasets since the bounding box annotations must be kept consistent throughout the transformations.
#
# Since the output of the detector network we train is an SxSx(B*5+C), we use an encoder to convert the original bounding box coordinates into relative grid bounding box coordinates corresponding to the expected output. We also use a decoder which allows us to convert the opposite direction into image coordinate bounding boxes.

# %%
file_root_train = 'data/VOCdevkit_2007/VOC2007/JPEGImages/'
annotation_file_train = 'data/voc2007.txt'

train_dataset = VocDetectorDataset(root_img_dir=file_root_train,dataset_file=annotation_file_train,train=True, S=S)
train_loader = DataLoader(train_dataset,batch_size=batch_size,shuffle=True,num_workers=2)
print('Loaded %d train images' % len(train_dataset))
# Out:
# Initializing dataset
# Loaded 5011 train images

# %%
file_root_test = 'data/VOCdevkit_2007/VOC2007test/JPEGImages/'
annotation_file_test = 'data/voc2007test.txt'

test_dataset = VocDetectorDataset(root_img_dir=file_root_test,dataset_file=annotation_file_test,train=False, S=S)
test_loader = DataLoader(test_dataset,batch_size=batch_size,shuffle=False,num_workers=2)
print('Loaded %d test images' % len(test_dataset))
# Out:
# Initializing dataset
# Loaded 4950 test images

# %%
data = train_dataset[0]

# %% [markdown]
# ## Set up training tools

# %%
criterion = YoloLoss(S, B, lambda_coord, lambda_noobj)
optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)

# %% [markdown]
# ## Train detector

# %%
best_test_loss = np.inf
learning_rate = 1e-3
for epoch in range(num_epochs):
    net.train()
    
    # Update learning rate late in training
    if epoch == 30 or epoch == 40:
        learning_rate /= 10.0

    for param_group in optimizer.param_groups:
        param_group['lr'] = learning_rate
    
    print('\n\nStarting epoch %d / %d' % (epoch + 1, num_epochs))
    print('Learning Rate for this epoch: {}'.format(learning_rate))
    
    total_loss = collections.defaultdict(int)
    
    for i, data in enumerate(train_loader):
        data = (item.to(device) for item in data)
        images, target_boxes, target_cls, has_object_map = data
        pred = net(images)
        loss_dict = criterion(pred, target_boxes, target_cls, has_object_map)
        for key in loss_dict:
            total_loss[key] += loss_dict[key].item()
        
        optimizer.zero_grad()
        loss_dict['total_loss'].backward()
        optimizer.step()
        
        if (i+1) % 50 == 0:
            outstring = 'Epoch [%d/%d], Iter [%d/%d], Loss: ' % ((epoch+1, num_epochs, i+1, len(train_loader)))
            outstring += ', '.join( "%s=%.3f" % (key[:-5], val / (i+1)) for key, val in total_loss.items() )
            print(outstring)
    
    # evaluate the network on the test data
    if (epoch + 1) % 5 == 0:
        test_aps = evaluate(net, test_dataset_file=annotation_file_test, img_root=file_root_test)
        print(epoch, test_aps)
    with torch.no_grad():
        test_loss = 0.0
        net.eval()
        for i, data in enumerate(test_loader):
            data = (item.to(device) for item in data)
            images, target_boxes, target_cls, has_object_map = data
            
            pred = net(images)
            loss_dict = criterion(pred, target_boxes, target_cls, has_object_map)
            test_loss += loss_dict['total_loss'].item()
        test_loss /= len(test_loader)
    
    if best_test_loss > test_loss:
        best_test_loss = test_loss
        print('Updating best test loss: %.5f' % best_test_loss)
        torch.save(net.state_dict(),'checkpoints/best_detector.pth')
    
    if (epoch+1) in [5, 10, 20, 30, 40]:
        torch.save(net.state_dict(),'checkpoints/detector_epoch_%d.pth' % (epoch+1))

    torch.save(net.state_dict(),'checkpoints/detector.pth')
# Out:
# Starting epoch 1 / 50
# Learning Rate for this epoch: 0.001
# Epoch [1/50], Iter [50/502], Loss: total=18.099, reg=3.664, containing_obj=0.210, no_obj=6.298, cls=7.927
# Epoch [1/50], Iter [100/502], Loss: total=13.760, reg=3.181, containing_obj=0.248, no_obj=3.896, cls=6.436
# Epoch [1/50], Iter [150/502], Loss: total=11.743, reg=2.966, containing_obj=0.287, no_obj=2.864, cls=5.626
# Epoch [1/50], Iter [200/502], Loss: total=10.583, reg=2.868, containing_obj=0.321, no_obj=2.285, cls=5.109
# Epoch [1/50], Iter [250/502], Loss: total=9.721, reg=2.769, containing_obj=0.341, no_obj=1.908, cls=4.702
# Epoch [1/50], Iter [300/502], Loss: total=9.069, reg=2.712, containing_obj=0.361, no_obj=1.640, cls=4.355
# Epoch [1/50], Iter [350/502], Loss: total=8.536, reg=2.642, containing_obj=0.372, no_obj=1.442, cls=4.080
# Epoch [1/50], Iter [400/502], Loss: total=8.187, reg=2.612, containing_obj=0.382, no_obj=1.289, cls=3.903
# Epoch [1/50], Iter [450/502], Loss: total=7.903, reg=2.586, containing_obj=0.393, no_obj=1.169, cls=3.755
# Epoch [1/50], Iter [500/502], Loss: total=7.633, reg=2.552, containing_obj=0.398, no_obj=1.071, cls=3.612
# Updating best test loss: 5.16092
#
#
# Starting epoch 2 / 50
# Learning Rate for this epoch: 0.001
# Epoch [2/50], Iter [50/502], Loss: total=5.116, reg=2.264, containing_obj=0.453, no_obj=0.184, cls=2.215
# Epoch [2/50], Iter [100/502], Loss: total=5.044, reg=2.240, containing_obj=0.439, no_obj=0.181, cls=2.183
# Epoch [2/50], Iter [150/502], Loss: total=5.029, reg=2.279, containing_obj=0.435, no_obj=0.179, cls=2.137
# Epoch [2/50], Iter [200/502], Loss: total=4.922, reg=2.243, containing_obj=0.426, no_obj=0.178, cls=2.074
# Epoch [2/50], Iter [250/502], Loss: total=4.900, reg=2.241, containing_obj=0.424, no_obj=0.177, cls=2.057
# Epoch [2/50], Iter [300/502], Loss: total=4.834, reg=2.219, containing_obj=0.421, no_obj=0.177, cls=2.017
# Epoch [2/50], Iter [350/502], Loss: total=4.773, reg=2.195, containing_obj=0.412, no_obj=0.175, cls=1.991
# Epoch [2/50], Iter [400/502], Loss: total=4.781, reg=2.208, containing_obj=0.410, no_obj=0.174, cls=1.989
# Epoch [2/50], Iter [450/502], Loss: total=4.759, reg=2.211, containing_obj=0.408, no_obj=0.173, cls=1.968
# Epoch [2/50], Iter [500/502], Loss: total=4.722, reg=2.210, containing_obj=0.404, no_obj=0.172, cls=1.937
# Updating best test loss: 4.56323
#
#
# Starting epoch 3 / 50
# Learning Rate for this epoch: 0.001
# Epoch [3/50], Iter [50/502], Loss: total=4.744, reg=2.272, containing_obj=0.409, no_obj=0.161, cls=1.902
# Epoch [3/50], Iter [100/502], Loss: total=4.615, reg=2.263, containing_obj=0.395, no_obj=0.160, cls=1.797
# Epoch [3/50], Iter [150/502], Loss: total=4.416, reg=2.162, containing_obj=0.373, no_obj=0.161, cls=1.720
# Epoch [3/50], Iter [200/502], Loss: total=4.344, reg=2.141, containing_obj=0.373, no_obj=0.161, cls=1.670
# Epoch [3/50], Iter [250/502], Loss: total=4.316, reg=2.121, containing_obj=0.368, no_obj=0.161, cls=1.666
# Epoch [3/50], Iter [300/502], Loss: total=4.320, reg=2.123, containing_obj=0.371, no_obj=0.160, cls=1.666
# Epoch [3/50], Iter [350/502], Loss: total=4.262, reg=2.094, containing_obj=0.366, no_obj=0.160, cls=1.641
# Epoch [3/50], Iter [400/502], Loss: total=4.246, reg=2.080, containing_obj=0.364, no_obj=0.160, cls=1.642
# Epoch [3/50], Iter [450/502], Loss: total=4.274, reg=2.096, containing_obj=0.366, no_obj=0.160, cls=1.652
# Epoch [3/50], Iter [500/502], Loss: total=4.238, reg=2.084, containing_obj=0.363, no_obj=0.160, cls=1.632
# Updating best test loss: 4.08264
#
#
# Starting epoch 4 / 50
# Learning Rate for this epoch: 0.001
# Epoch [4/50], Iter [50/502], Loss: total=4.264, reg=2.123, containing_obj=0.365, no_obj=0.161, cls=1.616
# Epoch [4/50], Iter [100/502], Loss: total=4.161, reg=2.098, containing_obj=0.349, no_obj=0.161, cls=1.554
# Epoch [4/50], Iter [150/502], Loss: total=4.042, reg=2.025, containing_obj=0.341, no_obj=0.161, cls=1.515
# Epoch [4/50], Iter [200/502], Loss: total=4.072, reg=2.037, containing_obj=0.347, no_obj=0.160, cls=1.528
# Epoch [4/50], Iter [250/502], Loss: total=4.057, reg=2.026, containing_obj=0.349, no_obj=0.160, cls=1.522
# Epoch [4/50], Iter [300/502], Loss: total=3.986, reg=1.997, containing_obj=0.345, no_obj=0.159, cls=1.485
# Epoch [4/50], Iter [350/502], Loss: total=3.994, reg=2.012, containing_obj=0.341, no_obj=0.158, cls=1.482
# Epoch [4/50], Iter [400/502], Loss: total=3.945, reg=1.992, containing_obj=0.337, no_obj=0.158, cls=1.458
# Epoch [4/50], Iter [450/502], Loss: total=3.929, reg=1.988, containing_obj=0.334, no_obj=0.158, cls=1.448
# Epoch [4/50], Iter [500/502], Loss: total=3.877, reg=1.968, containing_obj=0.331, no_obj=0.158, cls=1.421
# Updating best test loss: 3.82560
#
#
# Starting epoch 5 / 50
# Learning Rate for this epoch: 0.001
# Epoch [5/50], Iter [50/502], Loss: total=3.629, reg=1.875, containing_obj=0.307, no_obj=0.154, cls=1.293
# Epoch [5/50], Iter [100/502], Loss: total=3.586, reg=1.846, containing_obj=0.303, no_obj=0.153, cls=1.283
# Epoch [5/50], Iter [150/502], Loss: total=3.514, reg=1.828, containing_obj=0.301, no_obj=0.154, cls=1.231
# Epoch [5/50], Iter [200/502], Loss: total=3.565, reg=1.847, containing_obj=0.304, no_obj=0.154, cls=1.260
# Epoch [5/50], Iter [250/502], Loss: total=3.554, reg=1.846, containing_obj=0.300, no_obj=0.154, cls=1.253
# Epoch [5/50], Iter [300/502], Loss: total=3.614, reg=1.877, containing_obj=0.303, no_obj=0.153, cls=1.280
# Epoch [5/50], Iter [350/502], Loss: total=3.612, reg=1.882, containing_obj=0.303, no_obj=0.153, cls=1.273
# Epoch [5/50], Iter [400/502], Loss: total=3.596, reg=1.876, containing_obj=0.305, no_obj=0.154, cls=1.262
# Epoch [5/50], Iter [450/502], Loss: total=3.583, reg=1.876, containing_obj=0.305, no_obj=0.153, cls=1.248
# Epoch [5/50], Iter [500/502], Loss: total=3.579, reg=1.877, containing_obj=0.306, no_obj=0.153, cls=1.243
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [03:39<00:00, 22.50it/s]
# ---class aeroplane ap 0.07351777575489796---
# ---class bicycle ap 0.08481714109989372---
# ---class bird ap 0.06861706008653413---
# ---class boat ap 0.004752851711026616---
# ---class bottle ap 0.0018560844288322007---
# ---class bus ap 0.11908037029469166---
# ---class car ap 0.30968017128169867---
# ---class cat ap 0.2128222240191447---
# ---class chair ap 0.08299106161642525---
# ---class cow ap 0.03668032786885247---
# ---class diningtable ap 0.0024271844660194173---
# ---class dog ap 0.13034732079615022---
# ---class horse ap 0.29203651762938687---
# ---class motorbike ap 0.07070884415346461---
# ---class person ap 0.35570967674465626---
# ---class pottedplant ap 0.010232496488229055---
# ---class sheep ap 0.016036993309720582---
# ---class sofa ap 0.0--- (no predictions for this class)
# ---class train ap 0.25054318838643475---
# ---class tvmonitor ap 0.04901589439642856---
# ---map 0.10859365922662438---
# 4 [0.07351777575489796, 0.08481714109989372, 0.06861706008653413, 0.004752851711026616, 0.0018560844288322007, 0.11908037029469166, 0.30968017128169867, 0.2128222240191447, 0.08299106161642525, 0.03668032786885247, 0.0024271844660194173, 0.13034732079615022, 0.29203651762938687, 0.07070884415346461, 0.35570967674465626, 0.010232496488229055, 0.016036993309720582, 0.0, 0.25054318838643475, 0.04901589439642856]
# Updating best test loss: 3.56986
#
#
# Starting epoch 6 / 50
# Learning Rate for this epoch: 0.001
# Epoch [6/50], Iter [50/502], Loss: total=3.613, reg=1.974, containing_obj=0.300, no_obj=0.157, cls=1.182
# Epoch [6/50], Iter [100/502], Loss: total=3.508, reg=1.897, containing_obj=0.298, no_obj=0.154, cls=1.159
# Epoch [6/50], Iter [150/502], Loss: total=3.472, reg=1.888, containing_obj=0.297, no_obj=0.153, cls=1.134
# Epoch [6/50], Iter [200/502], Loss: total=3.479, reg=1.881, containing_obj=0.298, no_obj=0.152, cls=1.148
# Epoch [6/50], Iter [250/502], Loss: total=3.455, reg=1.868, containing_obj=0.295, no_obj=0.151, cls=1.141
# Epoch [6/50], Iter [300/502], Loss: total=3.430, reg=1.863, containing_obj=0.291, no_obj=0.150, cls=1.126
# Epoch [6/50], Iter [350/502], Loss: total=3.404, reg=1.855, containing_obj=0.290, no_obj=0.150, cls=1.109
# Epoch [6/50], Iter [400/502], Loss: total=3.418, reg=1.857, containing_obj=0.291, no_obj=0.150, cls=1.119
# Epoch [6/50], Iter [450/502], Loss: total=3.389, reg=1.844, containing_obj=0.290, no_obj=0.150, cls=1.106
# Epoch [6/50], Iter [500/502], Loss: total=3.385, reg=1.846, containing_obj=0.290, no_obj=0.149, cls=1.100
# Updating best test loss: 3.40912
#
#
# Starting epoch 7 / 50
# Learning Rate for this epoch: 0.001
# Epoch [7/50], Iter [50/502], Loss: total=3.326, reg=1.883, containing_obj=0.278, no_obj=0.152, cls=1.013
# Epoch [7/50], Iter [100/502], Loss: total=3.298, reg=1.875, containing_obj=0.275, no_obj=0.151, cls=0.997
# Epoch [7/50], Iter [150/502], Loss: total=3.273, reg=1.845, containing_obj=0.279, no_obj=0.149, cls=1.000
# Epoch [7/50], Iter [200/502], Loss: total=3.212, reg=1.806, containing_obj=0.279, no_obj=0.148, cls=0.978
# Epoch [7/50], Iter [250/502], Loss: total=3.221, reg=1.809, containing_obj=0.279, no_obj=0.148, cls=0.986
# Epoch [7/50], Iter [300/502], Loss: total=3.201, reg=1.795, containing_obj=0.277, no_obj=0.148, cls=0.981
# Epoch [7/50], Iter [350/502], Loss: total=3.224, reg=1.812, containing_obj=0.279, no_obj=0.148, cls=0.984
# Epoch [7/50], Iter [400/502], Loss: total=3.210, reg=1.802, containing_obj=0.280, no_obj=0.149, cls=0.979
# Epoch [7/50], Iter [450/502], Loss: total=3.200, reg=1.798, containing_obj=0.281, no_obj=0.149, cls=0.972
# Epoch [7/50], Iter [500/502], Loss: total=3.176, reg=1.783, containing_obj=0.277, no_obj=0.149, cls=0.966
# Updating best test loss: 3.20137
#
#
# Starting epoch 8 / 50
# Learning Rate for this epoch: 0.001
# Epoch [8/50], Iter [50/502], Loss: total=2.923, reg=1.662, containing_obj=0.266, no_obj=0.149, cls=0.847
# Epoch [8/50], Iter [100/502], Loss: total=3.034, reg=1.731, containing_obj=0.277, no_obj=0.150, cls=0.876
# Epoch [8/50], Iter [150/502], Loss: total=3.038, reg=1.737, containing_obj=0.275, no_obj=0.150, cls=0.876
# Epoch [8/50], Iter [200/502], Loss: total=3.023, reg=1.722, containing_obj=0.272, no_obj=0.150, cls=0.880
# Epoch [8/50], Iter [250/502], Loss: total=3.014, reg=1.723, containing_obj=0.272, no_obj=0.149, cls=0.869
# Epoch [8/50], Iter [300/502], Loss: total=3.029, reg=1.739, containing_obj=0.275, no_obj=0.150, cls=0.866
# Epoch [8/50], Iter [350/502], Loss: total=3.018, reg=1.724, containing_obj=0.273, no_obj=0.150, cls=0.871
# Epoch [8/50], Iter [400/502], Loss: total=3.010, reg=1.722, containing_obj=0.272, no_obj=0.150, cls=0.866
# Epoch [8/50], Iter [450/502], Loss: total=3.013, reg=1.726, containing_obj=0.269, no_obj=0.150, cls=0.868
# Epoch [8/50], Iter [500/502], Loss: total=2.997, reg=1.719, containing_obj=0.268, no_obj=0.150, cls=0.860
# Updating best test loss: 3.17504
#
#
# Starting epoch 9 / 50
# Learning Rate for this epoch: 0.001
# Epoch [9/50], Iter [50/502], Loss: total=2.780, reg=1.588, containing_obj=0.254, no_obj=0.148, cls=0.789
# Epoch [9/50], Iter [100/502], Loss: total=2.865, reg=1.661, containing_obj=0.265, no_obj=0.148, cls=0.792
# Epoch [9/50], Iter [150/502], Loss: total=3.009, reg=1.749, containing_obj=0.271, no_obj=0.147, cls=0.842
# Epoch [9/50], Iter [200/502], Loss: total=3.001, reg=1.746, containing_obj=0.272, no_obj=0.149, cls=0.834
# Epoch [9/50], Iter [250/502], Loss: total=2.951, reg=1.711, containing_obj=0.266, no_obj=0.149, cls=0.825
# Epoch [9/50], Iter [300/502], Loss: total=2.905, reg=1.692, containing_obj=0.263, no_obj=0.149, cls=0.802
# Epoch [9/50], Iter [350/502], Loss: total=2.894, reg=1.689, containing_obj=0.262, no_obj=0.150, cls=0.794
# Epoch [9/50], Iter [400/502], Loss: total=2.912, reg=1.705, containing_obj=0.260, no_obj=0.150, cls=0.797
# Epoch [9/50], Iter [450/502], Loss: total=2.897, reg=1.697, containing_obj=0.258, no_obj=0.150, cls=0.791
# Epoch [9/50], Iter [500/502], Loss: total=2.875, reg=1.682, containing_obj=0.257, no_obj=0.149, cls=0.786
# Updating best test loss: 3.00546
#
#
# Starting epoch 10 / 50
# Learning Rate for this epoch: 0.001
# Epoch [10/50], Iter [50/502], Loss: total=2.704, reg=1.625, containing_obj=0.249, no_obj=0.149, cls=0.681
# Epoch [10/50], Iter [100/502], Loss: total=2.682, reg=1.617, containing_obj=0.248, no_obj=0.147, cls=0.669
# Epoch [10/50], Iter [150/502], Loss: total=2.689, reg=1.617, containing_obj=0.246, no_obj=0.146, cls=0.680
# Epoch [10/50], Iter [200/502], Loss: total=2.709, reg=1.617, containing_obj=0.247, no_obj=0.146, cls=0.700
# Epoch [10/50], Iter [250/502], Loss: total=2.674, reg=1.597, containing_obj=0.243, no_obj=0.145, cls=0.688
# Epoch [10/50], Iter [300/502], Loss: total=2.691, reg=1.600, containing_obj=0.249, no_obj=0.145, cls=0.696
# Epoch [10/50], Iter [350/502], Loss: total=2.688, reg=1.597, containing_obj=0.250, no_obj=0.145, cls=0.696
# Epoch [10/50], Iter [400/502], Loss: total=2.701, reg=1.601, containing_obj=0.249, no_obj=0.145, cls=0.707
# Epoch [10/50], Iter [450/502], Loss: total=2.704, reg=1.604, containing_obj=0.251, no_obj=0.145, cls=0.704
# Epoch [10/50], Iter [500/502], Loss: total=2.693, reg=1.594, containing_obj=0.248, no_obj=0.145, cls=0.706
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [03:42<00:00, 22.21it/s]
# ---class aeroplane ap 0.4327722285957345---
# ---class bicycle ap 0.47527728967632454---
# ---class bird ap 0.3848331506666337---
# ---class boat ap 0.11578387654270213---
# ---class bottle ap 0.068591271437427---
# ---class bus ap 0.43260553266537904---
# ---class car ap 0.6006954777363136---
# ---class cat ap 0.5699563678678681---
# ---class chair ap 0.20935855059462188---
# ---class cow ap 0.15042535924860573---
# ---class diningtable ap 0.23882445666550312---
# ---class dog ap 0.46706004112505894---
# ---class horse ap 0.5079789359911486---
# ---class motorbike ap 0.33152413474031106---
# ---class person ap 0.4769475913880722---
# ---class pottedplant ap 0.08154860962890365---
# ---class sheep ap 0.2915664352467766---
# ---class sofa ap 0.2914910600837133---
# ---class train ap 0.4823824679550195---
# ---class tvmonitor ap 0.4008256539687417---
# ---map 0.350522424591243---
# 9 [0.4327722285957345, 0.47527728967632454, 0.3848331506666337, 0.11578387654270213, 0.068591271437427, 0.43260553266537904, 0.6006954777363136, 0.5699563678678681, 0.20935855059462188, 0.15042535924860573, 0.23882445666550312, 0.46706004112505894, 0.5079789359911486, 0.33152413474031106, 0.4769475913880722, 0.08154860962890365, 0.2915664352467766, 0.2914910600837133, 0.4823824679550195, 0.4008256539687417]
# Updating best test loss: 2.85651
#
#
# Starting epoch 11 / 50
# Learning Rate for this epoch: 0.001
# Epoch [11/50], Iter [50/502], Loss: total=2.568, reg=1.506, containing_obj=0.254, no_obj=0.147, cls=0.662
# Epoch [11/50], Iter [100/502], Loss: total=2.571, reg=1.532, containing_obj=0.249, no_obj=0.148, cls=0.642
# Epoch [11/50], Iter [150/502], Loss: total=2.567, reg=1.531, containing_obj=0.243, no_obj=0.148, cls=0.644
# Epoch [11/50], Iter [200/502], Loss: total=2.555, reg=1.533, containing_obj=0.237, no_obj=0.149, cls=0.635
# Epoch [11/50], Iter [250/502], Loss: total=2.595, reg=1.553, containing_obj=0.243, no_obj=0.148, cls=0.651
# Epoch [11/50], Iter [300/502], Loss: total=2.598, reg=1.558, containing_obj=0.245, no_obj=0.148, cls=0.646
# Epoch [11/50], Iter [350/502], Loss: total=2.593, reg=1.555, containing_obj=0.245, no_obj=0.149, cls=0.644
# Epoch [11/50], Iter [400/502], Loss: total=2.581, reg=1.554, containing_obj=0.243, no_obj=0.149, cls=0.636
# Epoch [11/50], Iter [450/502], Loss: total=2.575, reg=1.550, containing_obj=0.242, no_obj=0.148, cls=0.635
# Epoch [11/50], Iter [500/502], Loss: total=2.573, reg=1.543, containing_obj=0.243, no_obj=0.147, cls=0.639
# Updating best test loss: 2.78890
#
#
# Starting epoch 12 / 50
# Learning Rate for this epoch: 0.001
# Epoch [12/50], Iter [50/502], Loss: total=2.499, reg=1.498, containing_obj=0.238, no_obj=0.148, cls=0.616
# Epoch [12/50], Iter [100/502], Loss: total=2.519, reg=1.508, containing_obj=0.230, no_obj=0.146, cls=0.636
# Epoch [12/50], Iter [150/502], Loss: total=2.510, reg=1.517, containing_obj=0.234, no_obj=0.144, cls=0.614
# Epoch [12/50], Iter [200/502], Loss: total=2.478, reg=1.503, containing_obj=0.232, no_obj=0.144, cls=0.599
# Epoch [12/50], Iter [250/502], Loss: total=2.517, reg=1.526, containing_obj=0.237, no_obj=0.144, cls=0.609
# Epoch [12/50], Iter [300/502], Loss: total=2.506, reg=1.524, containing_obj=0.235, no_obj=0.145, cls=0.601
# Epoch [12/50], Iter [350/502], Loss: total=2.511, reg=1.526, containing_obj=0.235, no_obj=0.145, cls=0.604
# Epoch [12/50], Iter [400/502], Loss: total=2.524, reg=1.535, containing_obj=0.237, no_obj=0.145, cls=0.606
# Epoch [12/50], Iter [450/502], Loss: total=2.522, reg=1.534, containing_obj=0.237, no_obj=0.145, cls=0.606
# Epoch [12/50], Iter [500/502], Loss: total=2.522, reg=1.535, containing_obj=0.236, no_obj=0.146, cls=0.606
# Updating best test loss: 2.74342
#
#
# Starting epoch 13 / 50
# Learning Rate for this epoch: 0.001
# Epoch [13/50], Iter [50/502], Loss: total=2.478, reg=1.533, containing_obj=0.226, no_obj=0.146, cls=0.572
# Epoch [13/50], Iter [100/502], Loss: total=2.445, reg=1.505, containing_obj=0.220, no_obj=0.145, cls=0.575
# Epoch [13/50], Iter [150/502], Loss: total=2.471, reg=1.535, containing_obj=0.223, no_obj=0.145, cls=0.569
# Epoch [13/50], Iter [200/502], Loss: total=2.462, reg=1.531, containing_obj=0.222, no_obj=0.145, cls=0.564
# Epoch [13/50], Iter [250/502], Loss: total=2.454, reg=1.528, containing_obj=0.223, no_obj=0.145, cls=0.559
# Epoch [13/50], Iter [300/502], Loss: total=2.451, reg=1.516, containing_obj=0.226, no_obj=0.144, cls=0.565
# Epoch [13/50], Iter [350/502], Loss: total=2.458, reg=1.517, containing_obj=0.228, no_obj=0.143, cls=0.569
# Epoch [13/50], Iter [400/502], Loss: total=2.450, reg=1.510, containing_obj=0.227, no_obj=0.144, cls=0.568
# Epoch [13/50], Iter [450/502], Loss: total=2.452, reg=1.516, containing_obj=0.228, no_obj=0.144, cls=0.564
# Epoch [13/50], Iter [500/502], Loss: total=2.432, reg=1.500, containing_obj=0.228, no_obj=0.144, cls=0.560
# Updating best test loss: 2.70281
#
#
# Starting epoch 14 / 50
# Learning Rate for this epoch: 0.001
# Epoch [14/50], Iter [50/502], Loss: total=2.311, reg=1.412, containing_obj=0.219, no_obj=0.142, cls=0.538
# Epoch [14/50], Iter [100/502], Loss: total=2.470, reg=1.525, containing_obj=0.241, no_obj=0.141, cls=0.563
# Epoch [14/50], Iter [150/502], Loss: total=2.356, reg=1.445, containing_obj=0.226, no_obj=0.142, cls=0.544
# Epoch [14/50], Iter [200/502], Loss: total=2.392, reg=1.482, containing_obj=0.228, no_obj=0.142, cls=0.539
# Epoch [14/50], Iter [250/502], Loss: total=2.367, reg=1.479, containing_obj=0.223, no_obj=0.143, cls=0.522
# Epoch [14/50], Iter [300/502], Loss: total=2.337, reg=1.466, containing_obj=0.222, no_obj=0.144, cls=0.505
# Epoch [14/50], Iter [350/502], Loss: total=2.340, reg=1.464, containing_obj=0.225, no_obj=0.144, cls=0.507
# Epoch [14/50], Iter [400/502], Loss: total=2.350, reg=1.470, containing_obj=0.226, no_obj=0.144, cls=0.510
# Epoch [14/50], Iter [450/502], Loss: total=2.349, reg=1.470, containing_obj=0.225, no_obj=0.144, cls=0.511
# Epoch [14/50], Iter [500/502], Loss: total=2.370, reg=1.484, containing_obj=0.225, no_obj=0.144, cls=0.517
# Updating best test loss: 2.67188
#
#
# Starting epoch 15 / 50
# Learning Rate for this epoch: 0.001
# Epoch [15/50], Iter [50/502], Loss: total=2.358, reg=1.496, containing_obj=0.231, no_obj=0.147, cls=0.484
# Epoch [15/50], Iter [100/502], Loss: total=2.388, reg=1.498, containing_obj=0.231, no_obj=0.146, cls=0.513
# Epoch [15/50], Iter [150/502], Loss: total=2.317, reg=1.443, containing_obj=0.226, no_obj=0.147, cls=0.500
# Epoch [15/50], Iter [200/502], Loss: total=2.277, reg=1.424, containing_obj=0.221, no_obj=0.147, cls=0.486
# Epoch [15/50], Iter [250/502], Loss: total=2.246, reg=1.402, containing_obj=0.216, no_obj=0.145, cls=0.482
# Epoch [15/50], Iter [300/502], Loss: total=2.257, reg=1.415, containing_obj=0.215, no_obj=0.145, cls=0.482
# Epoch [15/50], Iter [350/502], Loss: total=2.243, reg=1.409, containing_obj=0.213, no_obj=0.143, cls=0.477
# Epoch [15/50], Iter [400/502], Loss: total=2.284, reg=1.439, containing_obj=0.218, no_obj=0.143, cls=0.485
# Epoch [15/50], Iter [450/502], Loss: total=2.283, reg=1.440, containing_obj=0.218, no_obj=0.144, cls=0.482
# Epoch [15/50], Iter [500/502], Loss: total=2.293, reg=1.448, containing_obj=0.218, no_obj=0.143, cls=0.483
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [03:40<00:00, 22.45it/s]
# ---class aeroplane ap 0.42961754337180547---
# ---class bicycle ap 0.5687795046476387---
# ---class bird ap 0.3639302143187606---
# ---class boat ap 0.1666039367113613---
# ---class bottle ap 0.15260297281753651---
# ---class bus ap 0.45954100631562933---
# ---class car ap 0.5820296887529918---
# ---class cat ap 0.6180601276367991---
# ---class chair ap 0.2729666302595447---
# ---class cow ap 0.35086891052024166---
# ---class diningtable ap 0.11745549773453091---
# ---class dog ap 0.5279585079878131---
# ---class horse ap 0.5448018398091414---
# ---class motorbike ap 0.41877930402436536---
# ---class person ap 0.5353520462987744---
# ---class pottedplant ap 0.10820627161035863---
# ---class sheep ap 0.33942484032842585---
# ---class sofa ap 0.4322103668331998---
# ---class train ap 0.47847945694211386---
# ---class tvmonitor ap 0.47259257860955006---
# ---map 0.3970130622765291---
# 14 [0.42961754337180547, 0.5687795046476387, 0.3639302143187606, 0.1666039367113613, 0.15260297281753651, 0.45954100631562933, 0.5820296887529918, 0.6180601276367991, 0.2729666302595447, 0.35086891052024166, 0.11745549773453091, 0.5279585079878131, 0.5448018398091414, 0.41877930402436536, 0.5353520462987744, 0.10820627161035863, 0.33942484032842585, 0.4322103668331998, 0.47847945694211386, 0.47259257860955006]
# Updating best test loss: 2.64517
#
#
# Starting epoch 16 / 50
# Learning Rate for this epoch: 0.001
# Epoch [16/50], Iter [50/502], Loss: total=1.982, reg=1.247, containing_obj=0.193, no_obj=0.147, cls=0.395
# Epoch [16/50], Iter [100/502], Loss: total=2.179, reg=1.377, containing_obj=0.219, no_obj=0.144, cls=0.439
# Epoch [16/50], Iter [150/502], Loss: total=2.133, reg=1.341, containing_obj=0.213, no_obj=0.143, cls=0.437
# Epoch [16/50], Iter [200/502], Loss: total=2.135, reg=1.346, containing_obj=0.210, no_obj=0.143, cls=0.435
# Epoch [16/50], Iter [250/502], Loss: total=2.159, reg=1.357, containing_obj=0.213, no_obj=0.143, cls=0.447
# Epoch [16/50], Iter [300/502], Loss: total=2.146, reg=1.353, containing_obj=0.209, no_obj=0.143, cls=0.441
# Epoch [16/50], Iter [350/502], Loss: total=2.178, reg=1.369, containing_obj=0.211, no_obj=0.142, cls=0.456
# Epoch [16/50], Iter [400/502], Loss: total=2.172, reg=1.364, containing_obj=0.211, no_obj=0.142, cls=0.456
# Epoch [16/50], Iter [450/502], Loss: total=2.177, reg=1.370, containing_obj=0.212, no_obj=0.141, cls=0.454
# Epoch [16/50], Iter [500/502], Loss: total=2.199, reg=1.386, containing_obj=0.214, no_obj=0.142, cls=0.458
# Updating best test loss: 2.60619
#
#
# Starting epoch 17 / 50
# Learning Rate for this epoch: 0.001
# Epoch [17/50], Iter [50/502], Loss: total=2.048, reg=1.304, containing_obj=0.205, no_obj=0.143, cls=0.396
# Epoch [17/50], Iter [100/502], Loss: total=2.101, reg=1.352, containing_obj=0.208, no_obj=0.143, cls=0.398
# Epoch [17/50], Iter [150/502], Loss: total=2.159, reg=1.376, containing_obj=0.208, no_obj=0.143, cls=0.432
# Epoch [17/50], Iter [200/502], Loss: total=2.107, reg=1.340, containing_obj=0.204, no_obj=0.142, cls=0.421
# Epoch [17/50], Iter [250/502], Loss: total=2.090, reg=1.325, containing_obj=0.202, no_obj=0.141, cls=0.422
# Epoch [17/50], Iter [300/502], Loss: total=2.091, reg=1.323, containing_obj=0.204, no_obj=0.141, cls=0.423
# Epoch [17/50], Iter [350/502], Loss: total=2.096, reg=1.327, containing_obj=0.205, no_obj=0.141, cls=0.424
# Epoch [17/50], Iter [400/502], Loss: total=2.124, reg=1.349, containing_obj=0.207, no_obj=0.141, cls=0.427
# Epoch [17/50], Iter [450/502], Loss: total=2.127, reg=1.353, containing_obj=0.206, no_obj=0.141, cls=0.427
# Epoch [17/50], Iter [500/502], Loss: total=2.150, reg=1.368, containing_obj=0.209, no_obj=0.141, cls=0.433
# Updating best test loss: 2.51706
#
#
# Starting epoch 18 / 50
# Learning Rate for this epoch: 0.001
# Epoch [18/50], Iter [50/502], Loss: total=1.974, reg=1.275, containing_obj=0.180, no_obj=0.142, cls=0.376
# Epoch [18/50], Iter [100/502], Loss: total=2.041, reg=1.312, containing_obj=0.198, no_obj=0.143, cls=0.388
# Epoch [18/50], Iter [150/502], Loss: total=2.039, reg=1.302, containing_obj=0.204, no_obj=0.141, cls=0.392
# Epoch [18/50], Iter [200/502], Loss: total=2.040, reg=1.305, containing_obj=0.200, no_obj=0.141, cls=0.395
# Epoch [18/50], Iter [250/502], Loss: total=2.045, reg=1.314, containing_obj=0.200, no_obj=0.140, cls=0.390
# Epoch [18/50], Iter [300/502], Loss: total=2.088, reg=1.338, containing_obj=0.203, no_obj=0.140, cls=0.407
# Epoch [18/50], Iter [350/502], Loss: total=2.089, reg=1.337, containing_obj=0.201, no_obj=0.140, cls=0.411
# Epoch [18/50], Iter [400/502], Loss: total=2.081, reg=1.335, containing_obj=0.200, no_obj=0.140, cls=0.406
# Epoch [18/50], Iter [450/502], Loss: total=2.087, reg=1.339, containing_obj=0.201, no_obj=0.140, cls=0.408
# Epoch [18/50], Iter [500/502], Loss: total=2.098, reg=1.344, containing_obj=0.203, no_obj=0.140, cls=0.410
# Updating best test loss: 2.51552
#
#
# Starting epoch 19 / 50
# Learning Rate for this epoch: 0.001
# Epoch [19/50], Iter [50/502], Loss: total=2.206, reg=1.400, containing_obj=0.233, no_obj=0.142, cls=0.431
# Epoch [19/50], Iter [100/502], Loss: total=2.072, reg=1.331, containing_obj=0.211, no_obj=0.144, cls=0.386
# Epoch [19/50], Iter [150/502], Loss: total=2.030, reg=1.308, containing_obj=0.201, no_obj=0.143, cls=0.377
# Epoch [19/50], Iter [200/502], Loss: total=2.031, reg=1.310, containing_obj=0.199, no_obj=0.143, cls=0.379
# Epoch [19/50], Iter [250/502], Loss: total=2.042, reg=1.316, containing_obj=0.200, no_obj=0.142, cls=0.383
# Epoch [19/50], Iter [300/502], Loss: total=2.037, reg=1.311, containing_obj=0.198, no_obj=0.142, cls=0.386
# Epoch [19/50], Iter [350/502], Loss: total=2.050, reg=1.321, containing_obj=0.201, no_obj=0.142, cls=0.386
# Epoch [19/50], Iter [400/502], Loss: total=2.062, reg=1.324, containing_obj=0.202, no_obj=0.141, cls=0.394
# Epoch [19/50], Iter [450/502], Loss: total=2.064, reg=1.329, containing_obj=0.202, no_obj=0.141, cls=0.393
# Epoch [19/50], Iter [500/502], Loss: total=2.080, reg=1.337, containing_obj=0.204, no_obj=0.140, cls=0.399
# Updating best test loss: 2.47265
#
#
# Starting epoch 20 / 50
# Learning Rate for this epoch: 0.001
# Epoch [20/50], Iter [50/502], Loss: total=1.979, reg=1.303, containing_obj=0.191, no_obj=0.139, cls=0.347
# Epoch [20/50], Iter [100/502], Loss: total=1.973, reg=1.270, containing_obj=0.190, no_obj=0.142, cls=0.371
# Epoch [20/50], Iter [150/502], Loss: total=2.014, reg=1.292, containing_obj=0.194, no_obj=0.141, cls=0.386
# Epoch [20/50], Iter [200/502], Loss: total=2.021, reg=1.311, containing_obj=0.193, no_obj=0.141, cls=0.376
# Epoch [20/50], Iter [250/502], Loss: total=1.999, reg=1.294, containing_obj=0.193, no_obj=0.141, cls=0.371
# Epoch [20/50], Iter [300/502], Loss: total=2.017, reg=1.306, containing_obj=0.196, no_obj=0.140, cls=0.376
# Epoch [20/50], Iter [350/502], Loss: total=2.025, reg=1.307, containing_obj=0.198, no_obj=0.140, cls=0.380
# Epoch [20/50], Iter [400/502], Loss: total=2.031, reg=1.309, containing_obj=0.198, no_obj=0.140, cls=0.384
# Epoch [20/50], Iter [450/502], Loss: total=2.044, reg=1.313, containing_obj=0.201, no_obj=0.140, cls=0.389
# Epoch [20/50], Iter [500/502], Loss: total=2.046, reg=1.317, containing_obj=0.199, no_obj=0.141, cls=0.390
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [03:46<00:00, 21.81it/s]
# ---class aeroplane ap 0.3318340749133757---
# ---class bicycle ap 0.5819899763767982---
# ---class bird ap 0.4648105635513536---
# ---class boat ap 0.20708051283413587---
# ---class bottle ap 0.1939174750754053---
# ---class bus ap 0.5593543156030182---
# ---class car ap 0.6572546062305737---
# ---class cat ap 0.6443767612842176---
# ---class chair ap 0.29659304163658096---
# ---class cow ap 0.33041428817570434---
# ---class diningtable ap 0.1304778974569621---
# ---class dog ap 0.5956506352063653---
# ---class horse ap 0.6400710426977401---
# ---class motorbike ap 0.4752472304724388---
# ---class person ap 0.5946951594475639---
# ---class pottedplant ap 0.1541676943875967---
# ---class sheep ap 0.4542079007885816---
# ---class sofa ap 0.4318065150777235---
# ---class train ap 0.5670030605052853---
# ---class tvmonitor ap 0.4844977783215911---
# ---map 0.43977252650215065---
# 19 [0.3318340749133757, 0.5819899763767982, 0.4648105635513536, 0.20708051283413587, 0.1939174750754053, 0.5593543156030182, 0.6572546062305737, 0.6443767612842176, 0.29659304163658096, 0.33041428817570434, 0.1304778974569621, 0.5956506352063653, 0.6400710426977401, 0.4752472304724388, 0.5946951594475639, 0.1541676943875967, 0.4542079007885816, 0.4318065150777235, 0.5670030605052853, 0.4844977783215911]
#
#
# Starting epoch 21 / 50
# Learning Rate for this epoch: 0.001
# Epoch [21/50], Iter [50/502], Loss: total=1.856, reg=1.209, containing_obj=0.177, no_obj=0.137, cls=0.334
# Epoch [21/50], Iter [100/502], Loss: total=1.928, reg=1.251, containing_obj=0.190, no_obj=0.138, cls=0.349
# Epoch [21/50], Iter [150/502], Loss: total=1.928, reg=1.248, containing_obj=0.191, no_obj=0.139, cls=0.350
# Epoch [21/50], Iter [200/502], Loss: total=1.961, reg=1.269, containing_obj=0.197, no_obj=0.138, cls=0.357
# Epoch [21/50], Iter [250/502], Loss: total=1.958, reg=1.269, containing_obj=0.197, no_obj=0.139, cls=0.352
# Epoch [21/50], Iter [300/502], Loss: total=2.000, reg=1.303, containing_obj=0.201, no_obj=0.140, cls=0.356
# Epoch [21/50], Iter [350/502], Loss: total=1.993, reg=1.294, containing_obj=0.201, no_obj=0.140, cls=0.358
# Epoch [21/50], Iter [400/502], Loss: total=1.995, reg=1.293, containing_obj=0.200, no_obj=0.140, cls=0.361
# Epoch [21/50], Iter [450/502], Loss: total=1.994, reg=1.292, containing_obj=0.199, no_obj=0.140, cls=0.363
# Epoch [21/50], Iter [500/502], Loss: total=1.993, reg=1.294, containing_obj=0.198, no_obj=0.140, cls=0.361
#
#
# Starting epoch 22 / 50
# Learning Rate for this epoch: 0.001
# Epoch [22/50], Iter [50/502], Loss: total=1.961, reg=1.284, containing_obj=0.205, no_obj=0.136, cls=0.336
# Epoch [22/50], Iter [100/502], Loss: total=1.997, reg=1.294, containing_obj=0.196, no_obj=0.141, cls=0.366
# Epoch [22/50], Iter [150/502], Loss: total=1.963, reg=1.283, containing_obj=0.192, no_obj=0.141, cls=0.347
# Epoch [22/50], Iter [200/502], Loss: total=1.998, reg=1.315, containing_obj=0.194, no_obj=0.141, cls=0.349
# Epoch [22/50], Iter [250/502], Loss: total=1.994, reg=1.306, containing_obj=0.193, no_obj=0.140, cls=0.355
# Epoch [22/50], Iter [300/502], Loss: total=1.987, reg=1.294, containing_obj=0.196, no_obj=0.140, cls=0.357
# Epoch [22/50], Iter [350/502], Loss: total=1.975, reg=1.288, containing_obj=0.193, no_obj=0.140, cls=0.353
# Epoch [22/50], Iter [400/502], Loss: total=1.967, reg=1.277, containing_obj=0.194, no_obj=0.139, cls=0.356
# Epoch [22/50], Iter [450/502], Loss: total=1.958, reg=1.272, containing_obj=0.194, no_obj=0.139, cls=0.353
# Epoch [22/50], Iter [500/502], Loss: total=1.959, reg=1.275, containing_obj=0.194, no_obj=0.139, cls=0.351
# Updating best test loss: 2.40888
#
#
# Starting epoch 23 / 50
# Learning Rate for this epoch: 0.001
# Epoch [23/50], Iter [50/502], Loss: total=1.806, reg=1.204, containing_obj=0.186, no_obj=0.136, cls=0.280
# Epoch [23/50], Iter [100/502], Loss: total=1.827, reg=1.193, containing_obj=0.190, no_obj=0.136, cls=0.309
# Epoch [23/50], Iter [150/502], Loss: total=1.841, reg=1.196, containing_obj=0.187, no_obj=0.137, cls=0.322
# Epoch [23/50], Iter [200/502], Loss: total=1.853, reg=1.207, containing_obj=0.188, no_obj=0.137, cls=0.320
# Epoch [23/50], Iter [250/502], Loss: total=1.858, reg=1.213, containing_obj=0.192, no_obj=0.138, cls=0.316
# Epoch [23/50], Iter [300/502], Loss: total=1.892, reg=1.237, containing_obj=0.194, no_obj=0.137, cls=0.324
# Epoch [23/50], Iter [350/502], Loss: total=1.888, reg=1.235, containing_obj=0.192, no_obj=0.137, cls=0.323
# Epoch [23/50], Iter [400/502], Loss: total=1.901, reg=1.242, containing_obj=0.193, no_obj=0.137, cls=0.328
# Epoch [23/50], Iter [450/502], Loss: total=1.904, reg=1.246, containing_obj=0.194, no_obj=0.138, cls=0.326
# Epoch [23/50], Iter [500/502], Loss: total=1.895, reg=1.238, containing_obj=0.191, no_obj=0.138, cls=0.327
#
#
# Starting epoch 24 / 50
# Learning Rate for this epoch: 0.001
# Epoch [24/50], Iter [50/502], Loss: total=1.874, reg=1.234, containing_obj=0.194, no_obj=0.131, cls=0.314
# Epoch [24/50], Iter [100/502], Loss: total=1.793, reg=1.163, containing_obj=0.191, no_obj=0.135, cls=0.304
# Epoch [24/50], Iter [150/502], Loss: total=1.791, reg=1.169, containing_obj=0.190, no_obj=0.134, cls=0.299
# Epoch [24/50], Iter [200/502], Loss: total=1.853, reg=1.222, containing_obj=0.193, no_obj=0.135, cls=0.303
# Epoch [24/50], Iter [250/502], Loss: total=1.867, reg=1.227, containing_obj=0.194, no_obj=0.135, cls=0.311
# Epoch [24/50], Iter [300/502], Loss: total=1.860, reg=1.216, containing_obj=0.192, no_obj=0.135, cls=0.316
# Epoch [24/50], Iter [350/502], Loss: total=1.873, reg=1.229, containing_obj=0.192, no_obj=0.136, cls=0.315
# Epoch [24/50], Iter [400/502], Loss: total=1.876, reg=1.233, containing_obj=0.191, no_obj=0.136, cls=0.317
# Epoch [24/50], Iter [450/502], Loss: total=1.867, reg=1.222, containing_obj=0.190, no_obj=0.136, cls=0.319
# Epoch [24/50], Iter [500/502], Loss: total=1.875, reg=1.227, containing_obj=0.191, no_obj=0.136, cls=0.322
#
#
# Starting epoch 25 / 50
# Learning Rate for this epoch: 0.001
# Epoch [25/50], Iter [50/502], Loss: total=1.835, reg=1.210, containing_obj=0.200, no_obj=0.137, cls=0.287
# Epoch [25/50], Iter [100/502], Loss: total=1.902, reg=1.261, containing_obj=0.191, no_obj=0.139, cls=0.311
# Epoch [25/50], Iter [150/502], Loss: total=1.880, reg=1.228, containing_obj=0.187, no_obj=0.139, cls=0.326
# Epoch [25/50], Iter [200/502], Loss: total=1.891, reg=1.232, containing_obj=0.186, no_obj=0.137, cls=0.336
# Epoch [25/50], Iter [250/502], Loss: total=1.855, reg=1.207, containing_obj=0.186, no_obj=0.138, cls=0.324
# Epoch [25/50], Iter [300/502], Loss: total=1.859, reg=1.211, containing_obj=0.185, no_obj=0.138, cls=0.325
# Epoch [25/50], Iter [350/502], Loss: total=1.853, reg=1.210, containing_obj=0.184, no_obj=0.137, cls=0.322
# Epoch [25/50], Iter [400/502], Loss: total=1.870, reg=1.226, containing_obj=0.184, no_obj=0.137, cls=0.323
# Epoch [25/50], Iter [450/502], Loss: total=1.850, reg=1.215, containing_obj=0.183, no_obj=0.137, cls=0.316
# Epoch [25/50], Iter [500/502], Loss: total=1.876, reg=1.232, containing_obj=0.186, no_obj=0.136, cls=0.322
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [03:41<00:00, 22.33it/s]
# ---class aeroplane ap 0.41531497281074686---
# ---class bicycle ap 0.5071372315487801---
# ---class bird ap 0.469000021443971---
# ---class boat ap 0.21553438682384382---
# ---class bottle ap 0.17975679245694737---
# ---class bus ap 0.541195424678405---
# ---class car ap 0.5661081701128039---
# ---class cat ap 0.6673658629696506---
# ---class chair ap 0.2712962913392285---
# ---class cow ap 0.32084715417052584---
# ---class diningtable ap 0.23614178594109647---
# ---class dog ap 0.6097651753095229---
# ---class horse ap 0.6578206495788836---
# ---class motorbike ap 0.4923817287557872---
# ---class person ap 0.5636613491047385---
# ---class pottedplant ap 0.11329029863723944---
# ---class sheep ap 0.5042561535113864---
# ---class sofa ap 0.4012216103670493---
# ---class train ap 0.49848181382726076---
# ---class tvmonitor ap 0.4481562788663604---
# ---map 0.4339366576127114---
# 24 [0.41531497281074686, 0.5071372315487801, 0.469000021443971, 0.21553438682384382, 0.17975679245694737, 0.541195424678405, 0.5661081701128039, 0.6673658629696506, 0.2712962913392285, 0.32084715417052584, 0.23614178594109647, 0.6097651753095229, 0.6578206495788836, 0.4923817287557872, 0.5636613491047385, 0.11329029863723944, 0.5042561535113864, 0.4012216103670493, 0.49848181382726076, 0.4481562788663604]
#
#
# Starting epoch 26 / 50
# Learning Rate for this epoch: 0.001
# Epoch [26/50], Iter [50/502], Loss: total=1.886, reg=1.255, containing_obj=0.179, no_obj=0.137, cls=0.315
# Epoch [26/50], Iter [100/502], Loss: total=1.939, reg=1.282, containing_obj=0.196, no_obj=0.136, cls=0.324
# Epoch [26/50], Iter [150/502], Loss: total=1.863, reg=1.228, containing_obj=0.187, no_obj=0.137, cls=0.311
# Epoch [26/50], Iter [200/502], Loss: total=1.844, reg=1.216, containing_obj=0.186, no_obj=0.136, cls=0.306
# Epoch [26/50], Iter [250/502], Loss: total=1.829, reg=1.205, containing_obj=0.184, no_obj=0.136, cls=0.304
# Epoch [26/50], Iter [300/502], Loss: total=1.803, reg=1.189, containing_obj=0.181, no_obj=0.136, cls=0.297
# Epoch [26/50], Iter [350/502], Loss: total=1.819, reg=1.201, containing_obj=0.183, no_obj=0.135, cls=0.299
# Epoch [26/50], Iter [400/502], Loss: total=1.817, reg=1.202, containing_obj=0.185, no_obj=0.135, cls=0.295
# Epoch [26/50], Iter [450/502], Loss: total=1.823, reg=1.206, containing_obj=0.186, no_obj=0.135, cls=0.296
# Epoch [26/50], Iter [500/502], Loss: total=1.806, reg=1.194, containing_obj=0.184, no_obj=0.135, cls=0.293
#
#
# Starting epoch 27 / 50
# Learning Rate for this epoch: 0.001
# Epoch [27/50], Iter [50/502], Loss: total=1.785, reg=1.158, containing_obj=0.180, no_obj=0.127, cls=0.319
# Epoch [27/50], Iter [100/502], Loss: total=1.912, reg=1.260, containing_obj=0.195, no_obj=0.129, cls=0.328
# Epoch [27/50], Iter [150/502], Loss: total=1.902, reg=1.250, containing_obj=0.191, no_obj=0.132, cls=0.329
# Epoch [27/50], Iter [200/502], Loss: total=1.856, reg=1.214, containing_obj=0.187, no_obj=0.134, cls=0.322
# Epoch [27/50], Iter [250/502], Loss: total=1.833, reg=1.196, containing_obj=0.184, no_obj=0.134, cls=0.318
# Epoch [27/50], Iter [300/502], Loss: total=1.809, reg=1.182, containing_obj=0.186, no_obj=0.134, cls=0.308
# Epoch [27/50], Iter [350/502], Loss: total=1.788, reg=1.173, containing_obj=0.182, no_obj=0.134, cls=0.298
# Epoch [27/50], Iter [400/502], Loss: total=1.781, reg=1.170, containing_obj=0.183, no_obj=0.134, cls=0.294
# Epoch [27/50], Iter [450/502], Loss: total=1.788, reg=1.176, containing_obj=0.184, no_obj=0.134, cls=0.294
# Epoch [27/50], Iter [500/502], Loss: total=1.802, reg=1.187, containing_obj=0.185, no_obj=0.135, cls=0.295
#
#
# Starting epoch 28 / 50
# Learning Rate for this epoch: 0.001
# Epoch [28/50], Iter [50/502], Loss: total=1.868, reg=1.249, containing_obj=0.179, no_obj=0.138, cls=0.302
# Epoch [28/50], Iter [100/502], Loss: total=1.857, reg=1.226, containing_obj=0.187, no_obj=0.136, cls=0.307
# Epoch [28/50], Iter [150/502], Loss: total=1.817, reg=1.192, containing_obj=0.184, no_obj=0.137, cls=0.305
# Epoch [28/50], Iter [200/502], Loss: total=1.782, reg=1.172, containing_obj=0.179, no_obj=0.137, cls=0.295
# Epoch [28/50], Iter [250/502], Loss: total=1.796, reg=1.179, containing_obj=0.183, no_obj=0.136, cls=0.298
# Epoch [28/50], Iter [300/502], Loss: total=1.798, reg=1.186, containing_obj=0.183, no_obj=0.135, cls=0.293
# Epoch [28/50], Iter [350/502], Loss: total=1.785, reg=1.178, containing_obj=0.183, no_obj=0.134, cls=0.289
# Epoch [28/50], Iter [400/502], Loss: total=1.785, reg=1.178, containing_obj=0.183, no_obj=0.135, cls=0.290
# Epoch [28/50], Iter [450/502], Loss: total=1.796, reg=1.183, containing_obj=0.185, no_obj=0.135, cls=0.293
# Epoch [28/50], Iter [500/502], Loss: total=1.792, reg=1.181, containing_obj=0.184, no_obj=0.134, cls=0.292
# Updating best test loss: 2.37605
#
#
# Starting epoch 29 / 50
# Learning Rate for this epoch: 0.001
# Epoch [29/50], Iter [50/502], Loss: total=1.784, reg=1.213, containing_obj=0.173, no_obj=0.135, cls=0.264
# Epoch [29/50], Iter [100/502], Loss: total=1.745, reg=1.173, containing_obj=0.175, no_obj=0.133, cls=0.263
# Epoch [29/50], Iter [150/502], Loss: total=1.758, reg=1.179, containing_obj=0.176, no_obj=0.133, cls=0.270
# Epoch [29/50], Iter [200/502], Loss: total=1.762, reg=1.169, containing_obj=0.181, no_obj=0.135, cls=0.276
# Epoch [29/50], Iter [250/502], Loss: total=1.735, reg=1.149, containing_obj=0.179, no_obj=0.135, cls=0.272
# Epoch [29/50], Iter [300/502], Loss: total=1.739, reg=1.154, containing_obj=0.180, no_obj=0.134, cls=0.271
# Epoch [29/50], Iter [350/502], Loss: total=1.731, reg=1.153, containing_obj=0.179, no_obj=0.135, cls=0.264
# Epoch [29/50], Iter [400/502], Loss: total=1.726, reg=1.149, containing_obj=0.178, no_obj=0.134, cls=0.265
# Epoch [29/50], Iter [450/502], Loss: total=1.733, reg=1.150, containing_obj=0.179, no_obj=0.134, cls=0.269
# Epoch [29/50], Iter [500/502], Loss: total=1.740, reg=1.155, containing_obj=0.179, no_obj=0.135, cls=0.272
# Updating best test loss: 2.37469
#
#
# Starting epoch 30 / 50
# Learning Rate for this epoch: 0.001
# Epoch [30/50], Iter [50/502], Loss: total=1.681, reg=1.137, containing_obj=0.182, no_obj=0.131, cls=0.232
# Epoch [30/50], Iter [100/502], Loss: total=1.677, reg=1.124, containing_obj=0.171, no_obj=0.135, cls=0.247
# Epoch [30/50], Iter [150/502], Loss: total=1.675, reg=1.121, containing_obj=0.171, no_obj=0.135, cls=0.248
# Epoch [30/50], Iter [200/502], Loss: total=1.672, reg=1.123, containing_obj=0.170, no_obj=0.133, cls=0.246
# Epoch [30/50], Iter [250/502], Loss: total=1.663, reg=1.114, containing_obj=0.172, no_obj=0.134, cls=0.244
# Epoch [30/50], Iter [300/502], Loss: total=1.673, reg=1.119, containing_obj=0.174, no_obj=0.134, cls=0.246
# Epoch [30/50], Iter [350/502], Loss: total=1.689, reg=1.128, containing_obj=0.174, no_obj=0.134, cls=0.253
# Epoch [30/50], Iter [400/502], Loss: total=1.703, reg=1.132, containing_obj=0.175, no_obj=0.134, cls=0.262
# Epoch [30/50], Iter [450/502], Loss: total=1.692, reg=1.123, containing_obj=0.174, no_obj=0.134, cls=0.261
# Epoch [30/50], Iter [500/502], Loss: total=1.698, reg=1.126, containing_obj=0.174, no_obj=0.134, cls=0.263
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [03:36<00:00, 22.82it/s]
# ---class aeroplane ap 0.5343225182970389---
# ---class bicycle ap 0.5492777996786559---
# ---class bird ap 0.49881038125868205---
# ---class boat ap 0.3053188160544967---
# ---class bottle ap 0.2647646620525697---
# ---class bus ap 0.6128629780697039---
# ---class car ap 0.6900671587753511---
# ---class cat ap 0.7134317463355573---
# ---class chair ap 0.30821780595395687---
# ---class cow ap 0.45580254950475296---
# ---class diningtable ap 0.3248603489286142---
# ---class dog ap 0.5667476911641168---
# ---class horse ap 0.6704981586094783---
# ---class motorbike ap 0.5034682960258695---
# ---class person ap 0.6097586024332194---
# ---class pottedplant ap 0.18520605159839754---
# ---class sheep ap 0.5070438985026089---
# ---class sofa ap 0.5401820999326004---
# ---class train ap 0.6430464548102155---
# ---class tvmonitor ap 0.5006941897286482---
# ---map 0.49921911038572675---
# 29 [0.5343225182970389, 0.5492777996786559, 0.49881038125868205, 0.3053188160544967, 0.2647646620525697, 0.6128629780697039, 0.6900671587753511, 0.7134317463355573, 0.30821780595395687, 0.45580254950475296, 0.3248603489286142, 0.5667476911641168, 0.6704981586094783, 0.5034682960258695, 0.6097586024332194, 0.18520605159839754, 0.5070438985026089, 0.5401820999326004, 0.6430464548102155, 0.5006941897286482]
#
#
# Starting epoch 31 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [31/50], Iter [50/502], Loss: total=1.589, reg=1.064, containing_obj=0.146, no_obj=0.136, cls=0.242
# Epoch [31/50], Iter [100/502], Loss: total=1.659, reg=1.128, containing_obj=0.164, no_obj=0.135, cls=0.232
# Epoch [31/50], Iter [150/502], Loss: total=1.630, reg=1.104, containing_obj=0.161, no_obj=0.135, cls=0.229
# Epoch [31/50], Iter [200/502], Loss: total=1.633, reg=1.100, containing_obj=0.166, no_obj=0.135, cls=0.232
# Epoch [31/50], Iter [250/502], Loss: total=1.623, reg=1.093, containing_obj=0.164, no_obj=0.135, cls=0.231
# Epoch [31/50], Iter [300/502], Loss: total=1.606, reg=1.083, containing_obj=0.164, no_obj=0.135, cls=0.224
# Epoch [31/50], Iter [350/502], Loss: total=1.599, reg=1.080, containing_obj=0.163, no_obj=0.135, cls=0.222
# Epoch [31/50], Iter [400/502], Loss: total=1.600, reg=1.083, containing_obj=0.162, no_obj=0.135, cls=0.220
# Epoch [31/50], Iter [450/502], Loss: total=1.592, reg=1.075, containing_obj=0.163, no_obj=0.135, cls=0.219
# Epoch [31/50], Iter [500/502], Loss: total=1.569, reg=1.059, containing_obj=0.160, no_obj=0.135, cls=0.215
# Updating best test loss: 2.23538
#
#
# Starting epoch 32 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [32/50], Iter [50/502], Loss: total=1.404, reg=0.929, containing_obj=0.157, no_obj=0.133, cls=0.185
# Epoch [32/50], Iter [100/502], Loss: total=1.453, reg=0.968, containing_obj=0.161, no_obj=0.132, cls=0.193
# Epoch [32/50], Iter [150/502], Loss: total=1.453, reg=0.975, containing_obj=0.157, no_obj=0.132, cls=0.190
# Epoch [32/50], Iter [200/502], Loss: total=1.469, reg=0.982, containing_obj=0.155, no_obj=0.132, cls=0.199
# Epoch [32/50], Iter [250/502], Loss: total=1.498, reg=1.005, containing_obj=0.159, no_obj=0.131, cls=0.203
# Epoch [32/50], Iter [300/502], Loss: total=1.513, reg=1.019, containing_obj=0.159, no_obj=0.131, cls=0.204
# Epoch [32/50], Iter [350/502], Loss: total=1.519, reg=1.027, containing_obj=0.160, no_obj=0.131, cls=0.201
# Epoch [32/50], Iter [400/502], Loss: total=1.516, reg=1.025, containing_obj=0.159, no_obj=0.131, cls=0.201
# Epoch [32/50], Iter [450/502], Loss: total=1.512, reg=1.021, containing_obj=0.160, no_obj=0.131, cls=0.199
# Epoch [32/50], Iter [500/502], Loss: total=1.508, reg=1.023, containing_obj=0.160, no_obj=0.131, cls=0.195
# Updating best test loss: 2.22173
#
#
# Starting epoch 33 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [33/50], Iter [50/502], Loss: total=1.450, reg=0.994, containing_obj=0.160, no_obj=0.136, cls=0.160
# Epoch [33/50], Iter [100/502], Loss: total=1.469, reg=0.997, containing_obj=0.162, no_obj=0.135, cls=0.174
# Epoch [33/50], Iter [150/502], Loss: total=1.471, reg=0.994, containing_obj=0.154, no_obj=0.135, cls=0.187
# Epoch [33/50], Iter [200/502], Loss: total=1.467, reg=0.989, containing_obj=0.153, no_obj=0.135, cls=0.190
# Epoch [33/50], Iter [250/502], Loss: total=1.481, reg=1.005, containing_obj=0.156, no_obj=0.133, cls=0.187
# Epoch [33/50], Iter [300/502], Loss: total=1.472, reg=0.997, containing_obj=0.155, no_obj=0.133, cls=0.187
# Epoch [33/50], Iter [350/502], Loss: total=1.468, reg=0.997, containing_obj=0.156, no_obj=0.133, cls=0.183
# Epoch [33/50], Iter [400/502], Loss: total=1.496, reg=1.017, containing_obj=0.159, no_obj=0.132, cls=0.188
# Epoch [33/50], Iter [450/502], Loss: total=1.493, reg=1.016, containing_obj=0.158, no_obj=0.132, cls=0.187
# Epoch [33/50], Iter [500/502], Loss: total=1.491, reg=1.016, containing_obj=0.159, no_obj=0.132, cls=0.185
# Updating best test loss: 2.19871
#
#
# Starting epoch 34 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [34/50], Iter [50/502], Loss: total=1.520, reg=1.024, containing_obj=0.179, no_obj=0.135, cls=0.182
# Epoch [34/50], Iter [100/502], Loss: total=1.497, reg=1.010, containing_obj=0.171, no_obj=0.135, cls=0.181
# Epoch [34/50], Iter [150/502], Loss: total=1.491, reg=1.015, containing_obj=0.166, no_obj=0.134, cls=0.176
# Epoch [34/50], Iter [200/502], Loss: total=1.484, reg=1.018, containing_obj=0.158, no_obj=0.134, cls=0.175
# Epoch [34/50], Iter [250/502], Loss: total=1.505, reg=1.026, containing_obj=0.160, no_obj=0.133, cls=0.186
# Epoch [34/50], Iter [300/502], Loss: total=1.500, reg=1.025, containing_obj=0.159, no_obj=0.133, cls=0.184
# Epoch [34/50], Iter [350/502], Loss: total=1.498, reg=1.022, containing_obj=0.157, no_obj=0.133, cls=0.186
# Epoch [34/50], Iter [400/502], Loss: total=1.476, reg=1.006, containing_obj=0.156, no_obj=0.133, cls=0.182
# Epoch [34/50], Iter [450/502], Loss: total=1.471, reg=1.003, containing_obj=0.156, no_obj=0.133, cls=0.180
# Epoch [34/50], Iter [500/502], Loss: total=1.475, reg=1.005, containing_obj=0.157, no_obj=0.132, cls=0.180
# Updating best test loss: 2.19690
#
#
# Starting epoch 35 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [35/50], Iter [50/502], Loss: total=1.504, reg=1.031, containing_obj=0.155, no_obj=0.129, cls=0.189
# Epoch [35/50], Iter [100/502], Loss: total=1.511, reg=1.044, containing_obj=0.155, no_obj=0.129, cls=0.182
# Epoch [35/50], Iter [150/502], Loss: total=1.464, reg=1.002, containing_obj=0.151, no_obj=0.129, cls=0.181
# Epoch [35/50], Iter [200/502], Loss: total=1.436, reg=0.978, containing_obj=0.153, no_obj=0.129, cls=0.175
# Epoch [35/50], Iter [250/502], Loss: total=1.423, reg=0.971, containing_obj=0.151, no_obj=0.130, cls=0.171
# ...
# Epoch [40/50], Iter [300/502], Loss: total=1.355, reg=0.918, containing_obj=0.149, no_obj=0.127, cls=0.161
# Epoch [40/50], Iter [350/502], Loss: total=1.350, reg=0.915, containing_obj=0.150, no_obj=0.127, cls=0.158
# Epoch [40/50], Iter [400/502], Loss: total=1.354, reg=0.916, containing_obj=0.149, no_obj=0.128, cls=0.161
# Epoch [40/50], Iter [450/502], Loss: total=1.365, reg=0.923, containing_obj=0.150, no_obj=0.128, cls=0.165
# Epoch [40/50], Iter [500/502], Loss: total=1.371, reg=0.924, containing_obj=0.152, no_obj=0.128, cls=0.167
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [03:35<00:00, 23.01it/s]
# ---class aeroplane ap 0.6201694077594317---
# ---class bicycle ap 0.6487777550981191---
# ---class bird ap 0.628610377784447---
# ---class boat ap 0.35203259553146743---
# ---class bottle ap 0.28713528100454616---
# ---class bus ap 0.6778729467284634---
# ---class car ap 0.7319565353984119---
# ---class cat ap 0.774335319003407---
# ---class chair ap 0.3481291058473063---
# ---class cow ap 0.5668422590558918---
# ---class diningtable ap 0.42674720226455043---
# ---class dog ap 0.6817902544817172---
# ---class horse ap 0.7383975847433366---
# ---class motorbike ap 0.6192439952632185---
# ---class person ap 0.6492097699941672---
# ---class pottedplant ap 0.25277064079968903---
# ---class sheep ap 0.5917479960989118---
# ---class sofa ap 0.5412396134535009---
# ---class train ap 0.7114784454716014---
# ---class tvmonitor ap 0.5389242100670425---
# ---map 0.5693705647924614---
# 39 [0.6201694077594317, 0.6487777550981191, 0.628610377784447, 0.35203259553146743, 0.28713528100454616, 0.6778729467284634, 0.7319565353984119, 0.774335319003407, 0.3481291058473063, 0.5668422590558918, 0.42674720226455043, 0.6817902544817172, 0.7383975847433366, 0.6192439952632185, 0.6492097699941672, 0.25277064079968903, 0.5917479960989118, 0.5412396134535009, 0.7114784454716014, 0.5389242100670425]
#
#
# Starting epoch 41 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [41/50], Iter [50/502], Loss: total=1.397, reg=0.947, containing_obj=0.148, no_obj=0.129, cls=0.172
# Epoch [41/50], Iter [100/502], Loss: total=1.380, reg=0.929, containing_obj=0.153, no_obj=0.129, cls=0.169
# Epoch [41/50], Iter [150/502], Loss: total=1.382, reg=0.931, containing_obj=0.151, no_obj=0.129, cls=0.170
# Epoch [41/50], Iter [200/502], Loss: total=1.396, reg=0.943, containing_obj=0.151, no_obj=0.130, cls=0.172
# Epoch [41/50], Iter [250/502], Loss: total=1.396, reg=0.951, containing_obj=0.153, no_obj=0.129, cls=0.163
# Epoch [41/50], Iter [300/502], Loss: total=1.382, reg=0.942, containing_obj=0.151, no_obj=0.129, cls=0.160
# Epoch [41/50], Iter [350/502], Loss: total=1.363, reg=0.929, containing_obj=0.148, no_obj=0.129, cls=0.157
# Epoch [41/50], Iter [400/502], Loss: total=1.359, reg=0.926, containing_obj=0.148, no_obj=0.128, cls=0.157
# Epoch [41/50], Iter [450/502], Loss: total=1.363, reg=0.930, containing_obj=0.148, no_obj=0.128, cls=0.156
# Epoch [41/50], Iter [500/502], Loss: total=1.353, reg=0.923, containing_obj=0.147, no_obj=0.129, cls=0.154
#
#
# Starting epoch 42 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [42/50], Iter [50/502], Loss: total=1.340, reg=0.928, containing_obj=0.149, no_obj=0.128, cls=0.135
# Epoch [42/50], Iter [100/502], Loss: total=1.346, reg=0.906, containing_obj=0.147, no_obj=0.129, cls=0.164
# Epoch [42/50], Iter [150/502], Loss: total=1.386, reg=0.936, containing_obj=0.151, no_obj=0.128, cls=0.172
# Epoch [42/50], Iter [200/502], Loss: total=1.415, reg=0.958, containing_obj=0.152, no_obj=0.128, cls=0.176
# Epoch [42/50], Iter [250/502], Loss: total=1.414, reg=0.964, containing_obj=0.152, no_obj=0.129, cls=0.169
# Epoch [42/50], Iter [300/502], Loss: total=1.413, reg=0.966, containing_obj=0.151, no_obj=0.129, cls=0.168
# Epoch [42/50], Iter [350/502], Loss: total=1.390, reg=0.949, containing_obj=0.147, no_obj=0.129, cls=0.165
# Epoch [42/50], Iter [400/502], Loss: total=1.373, reg=0.935, containing_obj=0.146, no_obj=0.129, cls=0.163
# Epoch [42/50], Iter [450/502], Loss: total=1.380, reg=0.942, containing_obj=0.148, no_obj=0.129, cls=0.162
# Epoch [42/50], Iter [500/502], Loss: total=1.380, reg=0.942, containing_obj=0.147, no_obj=0.129, cls=0.162
#
#
# Starting epoch 43 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [43/50], Iter [50/502], Loss: total=1.278, reg=0.866, containing_obj=0.143, no_obj=0.129, cls=0.139
# Epoch [43/50], Iter [100/502], Loss: total=1.344, reg=0.924, containing_obj=0.149, no_obj=0.127, cls=0.143
# Epoch [43/50], Iter [150/502], Loss: total=1.375, reg=0.947, containing_obj=0.150, no_obj=0.127, cls=0.151
# Epoch [43/50], Iter [200/502], Loss: total=1.355, reg=0.927, containing_obj=0.148, no_obj=0.127, cls=0.153
# Epoch [43/50], Iter [250/502], Loss: total=1.360, reg=0.929, containing_obj=0.146, no_obj=0.127, cls=0.157
# Epoch [43/50], Iter [300/502], Loss: total=1.346, reg=0.920, containing_obj=0.145, no_obj=0.127, cls=0.153
# Epoch [43/50], Iter [350/502], Loss: total=1.347, reg=0.920, containing_obj=0.146, no_obj=0.127, cls=0.155
# Epoch [43/50], Iter [400/502], Loss: total=1.349, reg=0.920, containing_obj=0.147, no_obj=0.127, cls=0.155
# Epoch [43/50], Iter [450/502], Loss: total=1.351, reg=0.920, containing_obj=0.148, no_obj=0.127, cls=0.157
# Epoch [43/50], Iter [500/502], Loss: total=1.351, reg=0.921, containing_obj=0.148, no_obj=0.127, cls=0.155
# Updating best test loss: 2.17415
#
#
# Starting epoch 44 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [44/50], Iter [50/502], Loss: total=1.268, reg=0.876, containing_obj=0.133, no_obj=0.130, cls=0.129
# Epoch [44/50], Iter [100/502], Loss: total=1.286, reg=0.873, containing_obj=0.141, no_obj=0.129, cls=0.144
# Epoch [44/50], Iter [150/502], Loss: total=1.319, reg=0.899, containing_obj=0.142, no_obj=0.129, cls=0.149
# Epoch [44/50], Iter [200/502], Loss: total=1.342, reg=0.915, containing_obj=0.144, no_obj=0.129, cls=0.154
# Epoch [44/50], Iter [250/502], Loss: total=1.352, reg=0.921, containing_obj=0.149, no_obj=0.128, cls=0.154
# Epoch [44/50], Iter [300/502], Loss: total=1.333, reg=0.907, containing_obj=0.148, no_obj=0.128, cls=0.150
# Epoch [44/50], Iter [350/502], Loss: total=1.339, reg=0.912, containing_obj=0.148, no_obj=0.128, cls=0.151
# Epoch [44/50], Iter [400/502], Loss: total=1.339, reg=0.912, containing_obj=0.149, no_obj=0.128, cls=0.150
# Epoch [44/50], Iter [450/502], Loss: total=1.339, reg=0.912, containing_obj=0.150, no_obj=0.128, cls=0.149
# Epoch [44/50], Iter [500/502], Loss: total=1.345, reg=0.920, containing_obj=0.149, no_obj=0.128, cls=0.148
# Updating best test loss: 2.17033
#
#
# Starting epoch 45 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [45/50], Iter [50/502], Loss: total=1.310, reg=0.876, containing_obj=0.157, no_obj=0.127, cls=0.150
# Epoch [45/50], Iter [100/502], Loss: total=1.340, reg=0.917, containing_obj=0.143, no_obj=0.126, cls=0.154
# Epoch [45/50], Iter [150/502], Loss: total=1.344, reg=0.926, containing_obj=0.145, no_obj=0.127, cls=0.146
# Epoch [45/50], Iter [200/502], Loss: total=1.372, reg=0.935, containing_obj=0.150, no_obj=0.128, cls=0.160
# Epoch [45/50], Iter [250/502], Loss: total=1.361, reg=0.927, containing_obj=0.147, no_obj=0.128, cls=0.158
# Epoch [45/50], Iter [300/502], Loss: total=1.368, reg=0.935, containing_obj=0.149, no_obj=0.128, cls=0.157
# Epoch [45/50], Iter [350/502], Loss: total=1.357, reg=0.927, containing_obj=0.146, no_obj=0.128, cls=0.156
# Epoch [45/50], Iter [400/502], Loss: total=1.364, reg=0.932, containing_obj=0.147, no_obj=0.128, cls=0.158
# Epoch [45/50], Iter [450/502], Loss: total=1.358, reg=0.927, containing_obj=0.148, no_obj=0.128, cls=0.155
# Epoch [45/50], Iter [500/502], Loss: total=1.362, reg=0.928, containing_obj=0.148, no_obj=0.128, cls=0.157
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [03:35<00:00, 22.97it/s]
# ---class aeroplane ap 0.6143580335017713---
# ---class bicycle ap 0.7042423630618763---
# ---class bird ap 0.620532260555523---
# ---class boat ap 0.35690918348918693---
# ---class bottle ap 0.29084854123850334---
# ---class bus ap 0.6630283929221288---
# ---class car ap 0.7259063814997775---
# ---class cat ap 0.7540964052672019---
# ---class chair ap 0.37459900057010875---
# ---class cow ap 0.5907158623747208---
# ---class diningtable ap 0.4466453079616035---
# ---class dog ap 0.7145718277021833---
# ---class horse ap 0.7345115864791124---
# ---class motorbike ap 0.6256496483536824---
# ---class person ap 0.6541588735343354---
# ---class pottedplant ap 0.24227314351560225---
# ---class sheep ap 0.5882524480014614---
# ---class sofa ap 0.5357096113317251---
# ---class train ap 0.6981431514689214---
# ---class tvmonitor ap 0.5284118910604527---
# ---map 0.5731781956944938---
# 44 [0.6143580335017713, 0.7042423630618763, 0.620532260555523, 0.35690918348918693, 0.29084854123850334, 0.6630283929221288, 0.7259063814997775, 0.7540964052672019, 0.37459900057010875, 0.5907158623747208, 0.4466453079616035, 0.7145718277021833, 0.7345115864791124, 0.6256496483536824, 0.6541588735343354, 0.24227314351560225, 0.5882524480014614, 0.5357096113317251, 0.6981431514689214, 0.5284118910604527]
#
#
# Starting epoch 46 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [46/50], Iter [50/502], Loss: total=1.412, reg=0.950, containing_obj=0.164, no_obj=0.126, cls=0.172
# Epoch [46/50], Iter [100/502], Loss: total=1.304, reg=0.878, containing_obj=0.149, no_obj=0.128, cls=0.149
# Epoch [46/50], Iter [150/502], Loss: total=1.336, reg=0.904, containing_obj=0.153, no_obj=0.129, cls=0.150
# Epoch [46/50], Iter [200/502], Loss: total=1.327, reg=0.908, containing_obj=0.149, no_obj=0.129, cls=0.141
# Epoch [46/50], Iter [250/502], Loss: total=1.342, reg=0.915, containing_obj=0.148, no_obj=0.129, cls=0.150
# Epoch [46/50], Iter [300/502], Loss: total=1.345, reg=0.914, containing_obj=0.148, no_obj=0.129, cls=0.155
# Epoch [46/50], Iter [350/502], Loss: total=1.340, reg=0.910, containing_obj=0.147, no_obj=0.128, cls=0.155
# Epoch [46/50], Iter [400/502], Loss: total=1.330, reg=0.904, containing_obj=0.146, no_obj=0.128, cls=0.152
# Epoch [46/50], Iter [450/502], Loss: total=1.341, reg=0.913, containing_obj=0.147, no_obj=0.128, cls=0.152
# Epoch [46/50], Iter [500/502], Loss: total=1.344, reg=0.916, containing_obj=0.146, no_obj=0.128, cls=0.153
#
#
# Starting epoch 47 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [47/50], Iter [50/502], Loss: total=1.277, reg=0.878, containing_obj=0.133, no_obj=0.130, cls=0.135
# Epoch [47/50], Iter [100/502], Loss: total=1.322, reg=0.911, containing_obj=0.142, no_obj=0.128, cls=0.140
# Epoch [47/50], Iter [150/502], Loss: total=1.346, reg=0.927, containing_obj=0.144, no_obj=0.127, cls=0.148
# Epoch [47/50], Iter [200/502], Loss: total=1.343, reg=0.922, containing_obj=0.143, no_obj=0.128, cls=0.151
# Epoch [47/50], Iter [250/502], Loss: total=1.337, reg=0.914, containing_obj=0.144, no_obj=0.128, cls=0.151
# Epoch [47/50], Iter [300/502], Loss: total=1.331, reg=0.906, containing_obj=0.144, no_obj=0.128, cls=0.153
# Epoch [47/50], Iter [350/502], Loss: total=1.315, reg=0.895, containing_obj=0.143, no_obj=0.128, cls=0.149
# Epoch [47/50], Iter [400/502], Loss: total=1.341, reg=0.916, containing_obj=0.146, no_obj=0.128, cls=0.151
# Epoch [47/50], Iter [450/502], Loss: total=1.340, reg=0.912, containing_obj=0.147, no_obj=0.128, cls=0.152
# Epoch [47/50], Iter [500/502], Loss: total=1.352, reg=0.921, containing_obj=0.149, no_obj=0.127, cls=0.155
#
#
# Starting epoch 48 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [48/50], Iter [50/502], Loss: total=1.449, reg=0.986, containing_obj=0.158, no_obj=0.122, cls=0.184
# Epoch [48/50], Iter [100/502], Loss: total=1.412, reg=0.965, containing_obj=0.152, no_obj=0.126, cls=0.169
# Epoch [48/50], Iter [150/502], Loss: total=1.402, reg=0.965, containing_obj=0.149, no_obj=0.126, cls=0.161
# Epoch [48/50], Iter [200/502], Loss: total=1.402, reg=0.971, containing_obj=0.150, no_obj=0.127, cls=0.154
# Epoch [48/50], Iter [250/502], Loss: total=1.402, reg=0.967, containing_obj=0.149, no_obj=0.127, cls=0.159
# Epoch [48/50], Iter [300/502], Loss: total=1.406, reg=0.966, containing_obj=0.150, no_obj=0.128, cls=0.162
# Epoch [48/50], Iter [350/502], Loss: total=1.386, reg=0.952, containing_obj=0.148, no_obj=0.128, cls=0.158
# Epoch [48/50], Iter [400/502], Loss: total=1.367, reg=0.938, containing_obj=0.146, no_obj=0.128, cls=0.155
# Epoch [48/50], Iter [450/502], Loss: total=1.348, reg=0.924, containing_obj=0.145, no_obj=0.128, cls=0.152
# Epoch [48/50], Iter [500/502], Loss: total=1.359, reg=0.933, containing_obj=0.146, no_obj=0.128, cls=0.152
#
#
# Starting epoch 49 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [49/50], Iter [50/502], Loss: total=1.365, reg=0.938, containing_obj=0.151, no_obj=0.129, cls=0.147
# Epoch [49/50], Iter [100/502], Loss: total=1.352, reg=0.927, containing_obj=0.149, no_obj=0.129, cls=0.147
# Epoch [49/50], Iter [150/502], Loss: total=1.326, reg=0.905, containing_obj=0.147, no_obj=0.129, cls=0.147
# Epoch [49/50], Iter [200/502], Loss: total=1.326, reg=0.900, containing_obj=0.148, no_obj=0.128, cls=0.149
# Epoch [49/50], Iter [250/502], Loss: total=1.330, reg=0.906, containing_obj=0.150, no_obj=0.128, cls=0.146
# Epoch [49/50], Iter [300/502], Loss: total=1.334, reg=0.910, containing_obj=0.151, no_obj=0.128, cls=0.146
# Epoch [49/50], Iter [350/502], Loss: total=1.349, reg=0.919, containing_obj=0.151, no_obj=0.128, cls=0.152
# Epoch [49/50], Iter [400/502], Loss: total=1.352, reg=0.921, containing_obj=0.152, no_obj=0.128, cls=0.152
# Epoch [49/50], Iter [450/502], Loss: total=1.360, reg=0.929, containing_obj=0.150, no_obj=0.128, cls=0.152
# Epoch [49/50], Iter [500/502], Loss: total=1.353, reg=0.924, containing_obj=0.149, no_obj=0.128, cls=0.152
#
#
# Starting epoch 50 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [50/50], Iter [50/502], Loss: total=1.312, reg=0.923, containing_obj=0.141, no_obj=0.127, cls=0.121
# Epoch [50/50], Iter [100/502], Loss: total=1.391, reg=0.958, containing_obj=0.162, no_obj=0.126, cls=0.145
# Epoch [50/50], Iter [150/502], Loss: total=1.385, reg=0.947, containing_obj=0.160, no_obj=0.127, cls=0.151
# Epoch [50/50], Iter [200/502], Loss: total=1.351, reg=0.917, containing_obj=0.154, no_obj=0.128, cls=0.152
# Epoch [50/50], Iter [250/502], Loss: total=1.326, reg=0.896, containing_obj=0.151, no_obj=0.128, cls=0.151
# Epoch [50/50], Iter [300/502], Loss: total=1.331, reg=0.900, containing_obj=0.152, no_obj=0.128, cls=0.152
# Epoch [50/50], Iter [350/502], Loss: total=1.319, reg=0.893, containing_obj=0.148, no_obj=0.128, cls=0.150
# Epoch [50/50], Iter [400/502], Loss: total=1.325, reg=0.898, containing_obj=0.146, no_obj=0.128, cls=0.153
# Epoch [50/50], Iter [450/502], Loss: total=1.333, reg=0.906, containing_obj=0.146, no_obj=0.128, cls=0.153
# Epoch [50/50], Iter [500/502], Loss: total=1.339, reg=0.912, containing_obj=0.147, no_obj=0.128, cls=0.153
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [03:42<00:00, 22.22it/s]
# ---class aeroplane ap 0.6256736867217108---
# ---class bicycle ap 0.6947812144576363---
# ---class bird ap 0.6286583908079297---
# ---class boat ap 0.3619641596861095---
# ---class bottle ap 0.29203434664495376---
# ---class bus ap 0.6600974572320837---
# ---class car ap 0.7289670673065465---
# ---class cat ap 0.7711954551809379---
# ---class chair ap 0.3632268299079413---
# ---class cow ap 0.5605506766509194---
# ---class diningtable ap 0.4532182466760145---
# ---class dog ap 0.688655068595075---
# ---class horse ap 0.7425123046410853---
# ---class motorbike ap 0.608137151575322---
# ---class person ap 0.6509354306208737---
# ---class pottedplant ap 0.25306643710293125---
# ---class sheep ap 0.6019718187782697---
# ---class sofa ap 0.5413898756779112---
# ---class train ap 0.7055457467606534---
# ---class tvmonitor ap 0.5488270232459845---
# ---map 0.5740704194135444---
# 49 [0.6256736867217108, 0.6947812144576363, 0.6286583908079297, 0.3619641596861095, 0.29203434664495376, 0.6600974572320837, 0.7289670673065465, 0.7711954551809379, 0.3632268299079413, 0.5605506766509194, 0.4532182466760145, 0.688655068595075, 0.7425123046410853, 0.608137151575322, 0.6509354306208737, 0.25306643710293125, 0.6019718187782697, 0.5413898756779112, 0.7055457467606534, 0.5488270232459845]

# %% [markdown]
# # View example predictions

# %%
net.eval()

# select random image from test set
image_name = random.choice(test_dataset.fnames)
image = cv2.imread(os.path.join(file_root_test, image_name))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

print('predicting...')
result = predict_image(net, image_name, root_img_directory=file_root_test)
for left_up, right_bottom, class_name, _, prob in result:
    color = COLORS[VOC_CLASSES.index(class_name)]
    cv2.rectangle(image, left_up, right_bottom, color, 2)
    label = class_name + str(round(prob, 2))
    text_size, baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
    p1 = (left_up[0], left_up[1] - text_size[1])
    cv2.rectangle(image, (p1[0] - 2 // 2, p1[1] - 2 - baseline), (p1[0] + text_size[0], p1[1] + text_size[1]),
                  color, -1)
    cv2.putText(image, label, (p1[0], p1[1] + baseline), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255, 255, 255), 1, 8)

plt.figure(figsize = (15,15))
plt.imshow(image)
# Out:
# predicting...

# %% [markdown]
# ## Evaluate on Test
#
# To evaluate detection results we use mAP (mean of average precision over each class)

# %%
test_aps = evaluate(net, test_dataset_file=annotation_file_test, img_root=file_root_test)
# Out:
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [03:40<00:00, 22.48it/s]
# ---class aeroplane ap 0.6256736867217108---
# ---class bicycle ap 0.6947812144576363---
# ---class bird ap 0.6286583908079297---
# ---class boat ap 0.3619641596861095---
# ---class bottle ap 0.29203434664495376---
# ---class bus ap 0.6600974572320837---
# ---class car ap 0.7289670673065465---
# ---class cat ap 0.7711954551809379---
# ---class chair ap 0.3632268299079413---
# ---class cow ap 0.5605506766509194---
# ---class diningtable ap 0.4532182466760145---
# ---class dog ap 0.688655068595075---
# ---class horse ap 0.7425123046410853---
# ---class motorbike ap 0.608137151575322---
# ---class person ap 0.6509354306208737---
# ---class pottedplant ap 0.25306643710293125---
# ---class sheep ap 0.6019718187782697---
# ---class sofa ap 0.5413898756779112---
# ---class train ap 0.7055457467606534---
# ---class tvmonitor ap 0.5488270232459845---
# ---map 0.5740704194135444---

# %% [markdown]
# ### Cell added to get intermediate mAP values for students

# %%
network_paths = ['./checkpoints/detector_epoch_%d.pth' % epoch for epoch in [5, 10, 20, 30, 40]]+['./checkpoints/detector.pth']
for load_network_path in network_paths:
    print('Loading saved network from {}'.format(load_network_path))
    net_loaded =  resnet50().to(device)
    net_loaded.load_state_dict(torch.load(load_network_path))
    evaluate(net_loaded, test_dataset_file=annotation_file_test, img_root=file_root_test)
# Out:
# Loading saved network from ./checkpoints/detector_epoch_5.pth
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [03:36<00:00, 22.85it/s]
# ---class aeroplane ap 0.07351777575489796---
# ---class bicycle ap 0.08481714109989372---
# ---class bird ap 0.06861706008653413---
# ---class boat ap 0.004752851711026616---
# ---class bottle ap 0.0018560844288322007---
# ---class bus ap 0.11908037029469166---
# ---class car ap 0.30968017128169867---
# ---class cat ap 0.2128222240191447---
# ---class chair ap 0.08299106161642525---
# ---class cow ap 0.03668032786885247---
# ---class diningtable ap 0.0024271844660194173---
# ---class dog ap 0.13034732079615022---
# ---class horse ap 0.29203651762938687---
# ---class motorbike ap 0.07070884415346461---
# ---class person ap 0.35570967674465626---
# ---class pottedplant ap 0.010232496488229055---
# ---class sheep ap 0.016036993309720582---
# ---class sofa ap 0.0--- (no predictions for this class)
# ---class train ap 0.25054318838643475---
# ---class tvmonitor ap 0.04901589439642856---
# ---map 0.10859365922662438---
# Loading saved network from ./checkpoints/detector_epoch_10.pth
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [03:41<00:00, 22.38it/s]
# ---class aeroplane ap 0.4327722285957345---
# ---class bicycle ap 0.47527728967632454---
# ---class bird ap 0.3848331506666337---
# ---class boat ap 0.11578387654270213---
# ---class bottle ap 0.068591271437427---
# ---class bus ap 0.43260553266537904---
# ---class car ap 0.6006954777363136---
# ---class cat ap 0.5699563678678681---
# ---class chair ap 0.20935855059462188---
# ---class cow ap 0.15042535924860573---
# ---class diningtable ap 0.23882445666550312---
# ---class dog ap 0.46706004112505894---
# ---class horse ap 0.5079789359911486---
# ---class motorbike ap 0.33152413474031106---
# ---class person ap 0.4769475913880722---
# ---class pottedplant ap 0.08154860962890365---
# ---class sheep ap 0.2915664352467766---
# ---class sofa ap 0.2914910600837133---
# ---class train ap 0.4823824679550195---
# ---class tvmonitor ap 0.4008256539687417---
# ---map 0.350522424591243---
# Loading saved network from ./checkpoints/detector_epoch_20.pth
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [03:39<00:00, 22.53it/s]
# ---class aeroplane ap 0.3318340749133757---
# ---class bicycle ap 0.5819899763767982---
# ---class bird ap 0.4648105635513536---
# ---class boat ap 0.20708051283413587---
# ---class bottle ap 0.1939174750754053---
# ---class bus ap 0.5593543156030182---
# ---class car ap 0.6572546062305737---
# ---class cat ap 0.6443767612842176---
# ---class chair ap 0.29659304163658096---
# ---class cow ap 0.33041428817570434---
# ---class diningtable ap 0.1304778974569621---
# ---class dog ap 0.5956506352063653---
# ---class horse ap 0.6400710426977401---
# ---class motorbike ap 0.4752472304724388---
# ---class person ap 0.5946951594475639---
# ---class pottedplant ap 0.1541676943875967---
# ---class sheep ap 0.4542079007885816---
# ---class sofa ap 0.4318065150777235---
# ---class train ap 0.5670030605052853---
# ---class tvmonitor ap 0.4844977783215911---
# ---map 0.43977252650215065---
# Loading saved network from ./checkpoints/detector_epoch_30.pth
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [03:48<00:00, 21.68it/s]
# ---class aeroplane ap 0.5343225182970389---
# ---class bicycle ap 0.5492777996786559---
# ---class bird ap 0.49881038125868205---
# ---class boat ap 0.3053188160544967---
# ---class bottle ap 0.2647646620525697---
# ---class bus ap 0.6128629780697039---
# ---class car ap 0.6900671587753511---
# ---class cat ap 0.7134317463355573---
# ---class chair ap 0.30821780595395687---
# ---class cow ap 0.45580254950475296---
# ---class diningtable ap 0.3248603489286142---
# ---class dog ap 0.5667476911641168---
# ---class horse ap 0.6704981586094783---
# ---class motorbike ap 0.5034682960258695---
# ---class person ap 0.6097586024332194---
# ---class pottedplant ap 0.18520605159839754---
# ---class sheep ap 0.5070438985026089---
# ---class sofa ap 0.5401820999326004---
# ---class train ap 0.6430464548102155---
# ---class tvmonitor ap 0.5006941897286482---
# ---map 0.49921911038572675---
# Loading saved network from ./checkpoints/detector_epoch_40.pth
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [03:42<00:00, 22.23it/s]
# ---class aeroplane ap 0.6201694077594317---
# ---class bicycle ap 0.6487777550981191---
# ---class bird ap 0.628610377784447---
# ---class boat ap 0.35203259553146743---
# ---class bottle ap 0.28713528100454616---
# ---class bus ap 0.6778729467284634---
# ---class car ap 0.7319565353984119---
# ---class cat ap 0.774335319003407---
# ---class chair ap 0.3481291058473063---
# ---class cow ap 0.5668422590558918---
# ---class diningtable ap 0.42674720226455043---
# ---class dog ap 0.6817902544817172---
# ---class horse ap 0.7383975847433366---
# ---class motorbike ap 0.6192439952632185---
# ---class person ap 0.6492097699941672---
# ---class pottedplant ap 0.25277064079968903---
# ---class sheep ap 0.5917479960989118---
# ---class sofa ap 0.5412396134535009---
# ---class train ap 0.7114784454716014---
# ---class tvmonitor ap 0.5389242100670425---
# ---map 0.5693705647924614---
# Loading saved network from ./checkpoints/detector.pth
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [03:41<00:00, 22.34it/s]
# ---class aeroplane ap 0.6256736867217108---
# ---class bicycle ap 0.6947812144576363---
# ---class bird ap 0.6286583908079297---
# ---class boat ap 0.3619641596861095---
# ---class bottle ap 0.29203434664495376---
# ---class bus ap 0.6600974572320837---
# ---class car ap 0.7289670673065465---
# ---class cat ap 0.7711954551809379---
# ---class chair ap 0.3632268299079413---
# ---class cow ap 0.5605506766509194---
# ---class diningtable ap 0.4532182466760145---
# ---class dog ap 0.688655068595075---
# ---class horse ap 0.7425123046410853---
# ---class motorbike ap 0.608137151575322---
# ---class person ap 0.6509354306208737---
# ---class pottedplant ap 0.25306643710293125---
# ---class sheep ap 0.6019718187782697---
# ---class sofa ap 0.5413898756779112---
# ---class train ap 0.7055457467606534---
# ---class tvmonitor ap 0.5488270232459845---
# ---map 0.5740704194135444---

# %%
output_submission_csv('my_new_solution.csv', test_aps)
